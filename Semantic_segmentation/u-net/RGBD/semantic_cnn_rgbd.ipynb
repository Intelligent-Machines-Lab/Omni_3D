# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Model, load_model
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Conv2DTranspose
from keras.layers import Activation, Dropout, Flatten, Dense, Input
from keras.layers.merge import concatenate, add
from keras.optimizers import Adam
import PIL as pil
import cv2

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import gc

plt.rcParams['figure.figsize'] = [15, 10]

# %%
# Reading from NY2 dataset
dataset_file = "C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\NY2.mat" # Windows
#dataset_file = "/home/lmariga/githubp/datasets/NY2.mat"

f = h5py.File(dataset_file, 'r')
images = np.array(f.get('images')).T
labels = np.array(f.get('labels'), dtype=np.uint16).T
depths = np.array(f.get('depths')).T
print(images.shape)
print(labels.shape)
print(depths.shape)
print(f.keys())
plt.subplot(2, 2, 1)
plt.title('RGB')
plt.imshow(images[:,:,:,0])
plt.subplot(2, 2, 2)
plt.title('Labels')
plt.imshow(labels[:,:,0])
plt.subplot(2, 2, 3)
plt.title('RGB')
plt.imshow(images[:,:,:,4])
plt.subplot(2, 2, 4)
plt.title('Labels')
plt.imshow(labels[:,:,4])
plt.show()
# Out:
# (480, 640, 3, 1449)
# (480, 640, 1449)
# (480, 640, 1449)
# <KeysViewHDF5 ['#refs#', '#subsystem#', 'accelData', 'depths', 'images', 'instances', 'labels', 'names', 'namesToIds', 'rawDepthFilenames', 'rawDepths', 'rawRgbFilenames', 'sceneTypes', 'scenes']>

# %%
# We take the labels list
data = []
for column in f['names']:
        row_data = []
        for row_number in range(len(column)):            
            row_data.append(''.join(map(chr, f[column[row_number]][:])))   
        data.append(row_data)
listanomes = data[0]

print(listanomes)
# Out:
# ['book', 'bottle', 'cabinet', 'ceiling', 'chair', 'cone', 'counter', 'dishwasher', 'faucet', 'fire extinguisher', 'floor', 'garbage bin', 'microwave', 'paper towel dispenser', 'paper', 'pot', 'refridgerator', 'stove burner', 'table', 'unknown', 'wall', 'bowl', 'magnet', 'sink', 'air vent', 'box', 'door knob', 'door', 'scissor', 'tape dispenser', 'telephone cord', 'telephone', 'track light', 'cork board', 'cup', 'desk', 'laptop', 'air duct', 'basket', 'camera', 'pipe', 'shelves', 'stacked chairs', 'styrofoam object', 'whiteboard', 'computer', 'keyboard', 'ladder', 'monitor', 'stand', 'bar', 'motion camera', 'projector screen', 'speaker', 'bag', 'clock', 'green screen', 'mantel', 'window', 'ball', 'hole puncher', 'light', 'manilla envelope', 'picture', 'mail shelf', 'printer', 'stapler', 'fax machine', 'folder', 'jar', 'magazine', 'ruler', 'cable modem', 'fan', 'file', 'hand sanitizer', 'paper rack', 'vase', 'air conditioner', 'blinds', 'flower', 'plant', 'sofa', 'stereo', 'books', 'exit sign', 'room divider', 'bookshelf', 'curtain', 'projector', 'modem', 'wire', 'water purifier', 'column', 'hooks', 'hanging hooks', 'pen', 'electrical outlet', 'doll', 'eraser', 'pencil holder', 'water carboy', 'mouse', 'cable rack', 'wire rack', 'flipboard', 'map', 'paper cutter', 'tape', 'thermostat', 'heater', 'circuit breaker box', 'paper towel', 'stamp', 'duster', 'poster case', 'whiteboard marker', 'ethernet jack', 'pillow', 'hair brush', 'makeup brush', 'mirror', 'shower curtain', 'toilet', 'toiletries bag', 'toothbrush holder', 'toothbrush', 'toothpaste', 'platter', 'rug', 'squeeze tube', 'shower cap', 'soap', 'towel rod', 'towel', 'bathtub', 'candle', 'tissue box', 'toilet paper', 'container', 'clothes', 'electric toothbrush', 'floor mat', 'lamp', 'drum', 'flower pot', 'banana', 'candlestick', 'shoe', 'stool', 'urn', 'earplugs', 'mailshelf', 'placemat', 'excercise ball', 'alarm clock', 'bed', 'night stand', 'deoderant', 'headphones', 'headboard', 'basketball hoop', 'foot rest', 'laundry basket', 'sock', 'football', 'mens suit', 'cable box', 'dresser', 'dvd player', 'shaver', 'television', 'contact lens solution bottle', 'drawer', 'remote control', 'cologne', 'stuffed animal', 'lint roller', 'tray', 'lock', 'purse', 'toy bottle', 'crate', 'vasoline', 'gift wrapping roll', 'wall decoration', 'hookah', 'radio', 'bicycle', 'pen box', 'mask', 'shorts', 'hat', 'hockey glove', 'hockey stick', 'vuvuzela', 'dvd', 'chessboard', 'suitcase', 'calculator', 'flashcard', 'staple remover', 'umbrella', 'bench', 'yoga mat', 'backpack', 'cd', 'sign', 'hangers', 'notebook', 'hanger', 'security camera', 'folders', 'clothing hanger', 'stairs', 'glass rack', 'saucer', 'tag', 'dolly', 'machine', 'trolly', 'shopping baskets', 'gate', 'bookrack', 'blackboard', 'coffee bag', 'coffee packet', 'hot water heater', 'muffins', 'napkin dispenser', 'plaque', 'plastic tub', 'plate', 'coffee machine', 'napkin holder', 'radiator', 'coffee grinder', 'oven', 'plant pot', 'scarf', 'spice rack', 'stove', 'tea kettle', 'napkin', 'bag of chips', 'bread', 'cutting board', 'dish brush', 'serving spoon', 'sponge', 'toaster', 'cooking pan', 'kitchen items', 'ladel', 'spatula', 'spice stand', 'trivet', 'knife rack', 'knife', 'baking dish', 'dish scrubber', 'drying rack', 'vessel', 'kichen towel', 'tin foil', 'kitchen utensil', 'utensil', 'blender', 'garbage bag', 'sink protector', 'box of ziplock bags', 'spice bottle', 'pitcher', 'pizza box', 'toaster oven', 'step stool', 'vegetable peeler', 'washing machine', 'can opener', 'can of food', 'paper towel holder', 'spoon stand', 'spoon', 'wooden kitchen utensils', 'bag of flour', 'fruit', 'sheet of metal', 'waffle maker', 'cake', 'cell phone', 'tv stand', 'tablecloth', 'wine glass', 'sculpture', 'wall stand', 'iphone', 'coke bottle', 'piano', 'wine rack', 'guitar', 'light switch', 'shirts in hanger', 'router', 'glass pot', 'cart', 'vacuum cleaner', 'bin', 'coins', 'hand sculpture', 'ipod', 'jersey', 'blanket', 'ironing board', 'pen stand' ...

# %%
# We can select the classes we want
class_floor = ['floor']
class_verticalPlanes = ['wall']
class_ceiling = ['ceiling']
class_structures = ['cabinet', 'refridgerator', 'table', 'door', 'desk', 'shelves', 'stacked chairs', 'whiteboard', 'window', 'bookshelf', 'column', 'wall divider', 'curtain'] # doors, windows, and other things that usually does not move

class_big_object = ['chair', 'cone', 'fire extinguisher', 'garbage bin', 'microwave', 'box', 'laptop', 'basket', 'computer', 'keyboard', 'monitor', 'ball', 'printer', 'fax machine','backpack']
class_small_object = ['book', 'bottle', 'paper', 'pot', 'bowl', 'scissor', 'cup', 'camera', 'bag', 'clock', 'picture', 'books', 'eraser', 'pencil holder', 'mouse', 'paper cutter', 'tape', 'circuit breaker box', 'paper towel', 'stamp','telephone', 'wire', 'head phones', 'mug holder', 'envelopes']

allowed_labels = class_verticalPlanes#+class_floor + class_ceiling + class_structures + class_big_object + class_small_object

# Finding indexes
allowed_labels_indexes = []
for i in allowed_labels: 
    allowed_labels_indexes.append(listanomes.index(i))

print(allowed_labels)
print(len(allowed_labels))
print(allowed_labels_indexes)
# Out:
# ['wall']
# 1
# [20]

# %%
# Exclui labels não usadas para treinar
labelsFinal = labels.astype(np.uint16, copy=False)
super_threshold_indices = np.isin(labelsFinal, np.asarray(allowed_labels_indexes)+1, invert=True)
labelsFinal[super_threshold_indices] = 0
super_threshold_indices = None
print(np.min(labelsFinal))
# Out:
# 0

# %%
gc.collect()
# Cria nova ordem numérica para as labels [1, 2, 3 ....]
def replace_with_dict2_generic(ar, dic, assume_all_present=0):
    # Extract out keys and values
    k = np.array(list(dic.keys()))
    v = np.array(list(dic.values()))

    # Get argsort indices
    sidx = k.argsort()

    ks = k[sidx]
    vs = v[sidx]
    idx = np.searchsorted(ks,ar)

    if assume_all_present==0:
        idx[idx==len(vs)] = 0
        mask = ks[idx] == ar
        return np.where(mask, vs[idx], ar)
    else:
        return vs[idx]
dictrans = {}
for i in range(len(allowed_labels_indexes)): 
    dictrans[allowed_labels_indexes[i]+1] = i+1
    

labelsFinal = replace_with_dict2_generic(labelsFinal, dictrans, False)
print(dictrans)
print(allowed_labels)
# Out:
# {21: 1}
# ['wall']

# %%
plt.subplot(2, 2, 1)
plt.title('RGB')
plt.imshow(labelsFinal[:,:,1])
plt.subplot(2, 2, 2)
plt.title('Labels')
plt.imshow(labelsFinal[:,:,2])
plt.subplot(2, 2, 3)
plt.title('RGB')
plt.imshow(labelsFinal[:,:,3])
plt.subplot(2, 2, 4)
plt.title('Labels')
plt.imshow(labelsFinal[:,:,4])
plt.show()

# %%
# Save array in a h5file
#images = np.array(f.get('images')).T
h5f = h5py.File('C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\filtered_labels_RGBD.h5', 'w')
h5f.create_dataset('labels', data=labels)
h5f.create_dataset('images', data=images)
h5f.create_dataset('depths', data=depths)
h5f.close()

# %% [markdown]
# # PART 2

# %%
# Reading files
dataset_file = "C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\filtered_labels_RGBD.h5" # Windows

f = h5py.File(dataset_file, 'r')
images = np.array(f.get('images'))
depths = np.array(f.get('depths'))
labels = np.array(f.get('labels'), dtype=np.uint16)

# Add depth information to image
depths = np.expand_dims(depths, axis=2)
images = np.append(images, depths, axis=2)

# Prepare to input in the network
images = np.moveaxis(images, -1, 0)
labels = np.moveaxis(labels, -1, 0)
labels = np.expand_dims(labels, axis=-1)

print(labels.shape)
print(images.shape)
# Out:
# (1449, 480, 640, 1)
# (1449, 480, 640, 4)

# %% [markdown]
# ## PREPARING THE U-NET

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x
  
def get_unet(input_img, nclasses=1, n_filters = 16, dropout = 0.1, batchnorm = True):
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)

    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)

    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)

    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)

    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)

    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)

    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)

    outputs = Conv2D(nclasses, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# Number of classes
num_classes = np.max(labels)
print(num_classes)

# Percentage of images used in validation step
pecentage_test = 0.8
divIndex = int(round(labels.shape[0]*pecentage_test))
images_train = images[ 0:divIndex, :, :, :]
images_valid = images[divIndex:, :, :, :]
label_train = labels[0:divIndex, :, :]
label_valid = labels[divIndex:,:, :]
print(images_train.shape)
print(images_valid.shape)

input_img = Input(images_train.shape[1:], name='img')
unet = get_unet(input_img)
unet.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
unet.summary()
# Out:
# 1
# (1159, 480, 640, 4)
# (290, 480, 640, 4)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 480, 640, 4)  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 480, 640, 16) 592         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 480, 640, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 480, 640, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 240, 320, 16) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 240, 320, 16) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 240, 320, 32) 4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 240, 320, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 240, 320, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 120, 160, 32) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 120, 160, 32) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 120, 160, 64) 18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 120, 160, 64) 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 120, 160, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 60, 80, 64)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 60, 80, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 60, 80, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 60, 80, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 60, 80, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 30, 40, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 30, 40, 128)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 30, 40, 256)  295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 30, 40, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 30, 40, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 60, 80, 128)  295040      activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 60, 80, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 60, 80, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 60, 80, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 60, 80, 128)  512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 60, 80, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 120, 160, 64) 73792       activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120, 160, 128 0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 120, 160, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 120, 160, 64) 73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 120, 160, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 120, 160, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 240, 320, 32) 18464       activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 240, 320, 64) 0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 240, 320, 64) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 240, 320, 32) 18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 240, 320, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 240, 320, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 480, 640, 16) 4624        activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 480, 640, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 480, 640, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 480, 640, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 480, 640, 16) 64          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 480, 640, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 480, 640, 1)  17          activation_18[0][0]
# ==================================================================================================
# Total params: 1,179,553
# Trainable params: 1,178,081
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
print(images_train.shape)
print(label_train.shape)
print(images_valid.shape)
print(label_valid.shape)
# Out:
# (1159, 480, 640, 4)
# (1159, 480, 640, 1)
# (290, 480, 640, 4)
# (290, 480, 640, 1)

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('rgbd_nyu2_v1.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

results = unet.fit(images_train, label_train, batch_size=8, epochs=100, callbacks=callbacks,
                    validation_data=(images_valid, label_valid))
# Out:
# Train on 1159 samples, validate on 290 samples
# Epoch 1/100
# 1159/1159 [==============================] - 141s 122ms/step - loss: 0.4561 - accuracy: 0.7785 - val_loss: 0.5930 - val_accuracy: 0.6605
#
# Epoch 00001: val_loss improved from inf to 0.59300, saving model to rgbd_nyu2_v1.h5
# Epoch 2/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3831 - accuracy: 0.8233 - val_loss: 0.4344 - val_accuracy: 0.7619
#
# Epoch 00002: val_loss improved from 0.59300 to 0.43437, saving model to rgbd_nyu2_v1.h5
# Epoch 3/100
# 1159/1159 [==============================] - 132s 114ms/step - loss: 0.3670 - accuracy: 0.8337 - val_loss: 0.3352 - val_accuracy: 0.8450
#
# Epoch 00003: val_loss improved from 0.43437 to 0.33521, saving model to rgbd_nyu2_v1.h5
# Epoch 4/100
# 1159/1159 [==============================] - 132s 114ms/step - loss: 0.3563 - accuracy: 0.8402 - val_loss: 0.3200 - val_accuracy: 0.8584
#
# Epoch 00004: val_loss improved from 0.33521 to 0.31998, saving model to rgbd_nyu2_v1.h5
# Epoch 5/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3510 - accuracy: 0.8444 - val_loss: 0.3203 - val_accuracy: 0.8509
#
# Epoch 00005: val_loss did not improve from 0.31998
# Epoch 6/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3460 - accuracy: 0.8459 - val_loss: 0.3999 - val_accuracy: 0.7989
#
# Epoch 00006: val_loss did not improve from 0.31998
# Epoch 7/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3371 - accuracy: 0.8517 - val_loss: 0.3088 - val_accuracy: 0.8634
#
# Epoch 00007: val_loss improved from 0.31998 to 0.30879, saving model to rgbd_nyu2_v1.h5
# Epoch 8/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3309 - accuracy: 0.8575 - val_loss: 0.3547 - val_accuracy: 0.8338
#
# Epoch 00008: val_loss did not improve from 0.30879
# Epoch 9/100
# 1159/1159 [==============================] - 132s 114ms/step - loss: 0.3276 - accuracy: 0.8580 - val_loss: 0.2962 - val_accuracy: 0.8719
#
# Epoch 00009: val_loss improved from 0.30879 to 0.29624, saving model to rgbd_nyu2_v1.h5
# Epoch 10/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.3233 - accuracy: 0.8604 - val_loss: 0.2990 - val_accuracy: 0.8671
#
# Epoch 00010: val_loss did not improve from 0.29624
# Epoch 11/100
# 1159/1159 [==============================] - 133s 114ms/step - loss: 0.3196 - accuracy: 0.8632 - val_loss: 0.3308 - val_accuracy: 0.8563
#
# Epoch 00011: val_loss did not improve from 0.29624
# Epoch 12/100
# 1159/1159 [==============================] - 132s 114ms/step - loss: 0.3160 - accuracy: 0.8649 - val_loss: 0.3142 - val_accuracy: 0.8655
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00012: val_loss did not improve from 0.29624
# Epoch 13/100
# 1159/1159 [==============================] - 133s 114ms/step - loss: 0.2997 - accuracy: 0.8734 - val_loss: 0.3057 - val_accuracy: 0.8695
#
# Epoch 00013: val_loss did not improve from 0.29624
# Epoch 14/100
# 1159/1159 [==============================] - 134s 115ms/step - loss: 0.2965 - accuracy: 0.8759 - val_loss: 0.2998 - val_accuracy: 0.8725
#
# Epoch 00014: val_loss did not improve from 0.29624
# Epoch 15/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.2904 - accuracy: 0.8779 - val_loss: 0.2878 - val_accuracy: 0.8792
#
# Epoch 00015: val_loss improved from 0.29624 to 0.28776, saving model to rgbd_nyu2_v1.h5
# Epoch 16/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.2879 - accuracy: 0.8793 - val_loss: 0.3055 - val_accuracy: 0.8721
#
# Epoch 00016: val_loss did not improve from 0.28776
# Epoch 17/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.2907 - accuracy: 0.8769 - val_loss: 0.3146 - val_accuracy: 0.8673
#
# Epoch 00017: val_loss did not improve from 0.28776
# Epoch 18/100
# 1159/1159 [==============================] - 134s 115ms/step - loss: 0.2898 - accuracy: 0.8785 - val_loss: 0.2982 - val_accuracy: 0.8762
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00018: val_loss did not improve from 0.28776
# Epoch 19/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.2885 - accuracy: 0.8785 - val_loss: 0.3057 - val_accuracy: 0.8725
#
# Epoch 00019: val_loss did not improve from 0.28776
# Epoch 20/100
# 1159/1159 [==============================] - 132s 114ms/step - loss: 0.2880 - accuracy: 0.8791 - val_loss: 0.3123 - val_accuracy: 0.8692
#
# Epoch 00020: val_loss did not improve from 0.28776
# Epoch 21/100
# 1159/1159 [==============================] - 133s 115ms/step - loss: 0.2851 - accuracy: 0.8803 - val_loss: 0.3116 - val_accuracy: 0.8697
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00021: val_loss did not improve from 0.28776
# Epoch 22/100
# 1159/1159 [==============================] - 134s 115ms/step - loss: 0.2840 - accuracy: 0.8811 - val_loss: 0.3122 - val_accuracy: 0.8691
#
# Epoch 00022: val_loss did not improve from 0.28776
# Epoch 23/100
# 1159/1159 [==============================] - 134s 116ms/step - loss: 0.2852 - accuracy: 0.8795 - val_loss: 0.3156 - val_accuracy: 0.8683
#
# Epoch 00023: val_loss did not improve from 0.28776
# Epoch 24/100
# 1159/1159 [==============================] - 134s 116ms/step - loss: 0.2836 - accuracy: 0.8807 - val_loss: 0.3152 - val_accuracy: 0.8685
#
# Epoch 00024: val_loss did not improve from 0.28776
# Epoch 25/100
# 1159/1159 [==============================] - 134s 115ms/step - loss: 0.2831 - accuracy: 0.8812 - val_loss: 0.3142 - val_accuracy: 0.8689
#
# Epoch 00025: val_loss did not improve from 0.28776
# Epoch 00025: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
unet.save("rgbd_nyu2_v1_model.h5")

# %% [markdown]
# ## PARTE 3

# %%
# Load best model

# RGB only v1
unet = load_model("rgbd_nyu2_v1_model.h5")
unet.load_weights('rgbd_nyu2_v1.h5')



# Reading files
dataset_file = "C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\filtered_labels_RGBD.h5" # Windows

f = h5py.File(dataset_file, 'r')
images = np.array(f.get('images'))
depths = np.array(f.get('depths'))
labels = np.array(f.get('labels'), dtype=np.uint16)

# Add depth information to image
depths = np.expand_dims(depths, axis=2)
images = np.append(images, depths, axis=2)

# Prepare to input in the network
images = np.moveaxis(images, -1, 0)
labels = np.moveaxis(labels, -1, 0)
labels = np.expand_dims(labels, axis=-1)

print(labels.shape)
print(images.shape)
# Out:
# (1449, 480, 640, 1)
# (1449, 480, 640, 4)

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
unet.evaluate(images, labels, verbose=1)
# Out:
# 1449/1449 [==============================] - 72s 49ms/step
# [0.32108899267111424, 0.8618790507316589]

# %%
# Predict on train, val and test
preds_train = unet.predict(images, verbose=1)
# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
# Out:
# 1449/1449 [==============================] - 61s 42ms/step

# %%
import random
i1 = random.randint(0, 1159)
i2 = random.randint(0, 1159)
i3 = random.randint(0, 1159)
imgs = images[:, :, :, :3].astype('uint8')
print(imgs.shape)
print(np.max(imgs[:,:, :,1]))
plt.subplot(3, 3, 1)
plt.title('RGB')
plt.imshow(imgs[i1,:,:,:])
plt.subplot(3, 3, 2)
plt.title('gt')
plt.imshow(labels[i1,:,:])
plt.subplot(3, 3, 3)
plt.title('predict')
plt.imshow(preds_train_t[i1,:,:])

plt.subplot(3, 3, 4)
plt.title('RGB')
plt.imshow(imgs[i2,:,:])
plt.subplot(3, 3, 5)
plt.title('gt')
plt.imshow(labels[i2,:,:])
plt.subplot(3, 3, 6)
plt.title('predict')
plt.imshow(preds_train_t[i2,:,:])
plt.show()

plt.subplot(3, 3, 7)
plt.title('RGB')
plt.imshow(imgs[i3,:,:])
plt.subplot(3, 3, 8)
plt.title('gt')
plt.imshow(labels[i3,:,:])
plt.subplot(3, 3, 9)
plt.title('predict')
plt.imshow(preds_train_t[i3,:,:])
plt.show()
# Out:
# (1449, 480, 640, 3)
# 255

# %%
test1 = plt.imread("C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\Omni\\Semantic_segmentation\\1_rgb.jpg")
test2 = plt.imread("C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\Omni\\Semantic_segmentation\\2_rgb.jpg")
test1d = plt.imread("C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\Omni\\Semantic_segmentation\\1_depth.png")
test2d = plt.imread("C:\\Users\\Avell\\Desktop\\ITA\\Tese mestrado\\robo\\Omni\\Semantic_segmentation\\2_depth.png")
test1dim = np.expand_dims(test1, axis=0)
test2dim = np.expand_dims(test2, axis=0)
test1dimd = np.expand_dims(test1d, axis=0)
test2dimd = np.expand_dims(test2d, axis=0)
test1dimd = np.expand_dims(test1dimd, axis=-1)
test2dimd = np.expand_dims(test2dimd, axis=-1)
print(test1dim.shape)
print(test2dim.shape)
print(test1dimd.shape)
print(test2dimd.shape)

rgbd_teste1 = np.append(test1dim, test1dimd, axis=3)
rgbd_teste2 = np.append(test2dim, test2dimd, axis=3)
rgbd_teste_total = np.append(rgbd_teste1, rgbd_teste2, axis=0)
print(rgbd_teste1.shape)
print(rgbd_teste2.shape)
print(rgbd_teste_total.shape)

# print(testdim.shape)
test_label = unet.predict(rgbd_teste_total, verbose=1)
test_label = (test_label > 0.5).astype(np.uint8)
plt.subplot(2, 2, 1)
plt.title('RGB')
plt.imshow(test1)
plt.subplot(2, 2, 2)
plt.title('gt')
plt.imshow(test_label[0,:, :, :])
plt.subplot(2, 2, 3)
plt.title('RGB')
plt.imshow(test2)
plt.subplot(2, 2, 4)
plt.title('gt')
plt.imshow(test_label[1,:, :, :])

print(test_label[0,:, :, :].shape)

im = pil.Image.fromarray(test_label[0,:, :, 0])
im.save("1_mask.png", "PNG")

im = pil.Image.fromarray(test_label[1,:, :, 0])
im.save("2_mask.png", "PNG")
# Out:
# (1, 480, 640, 3)
# (1, 480, 640, 3)
# (1, 480, 640, 1)
# (1, 480, 640, 1)
# (1, 480, 640, 4)
# (1, 480, 640, 4)
# (2, 480, 640, 4)
# 2/2 [==============================] - 1s 272ms/step
# (480, 640, 1)
